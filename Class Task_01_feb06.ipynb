# %%
Feb 06 Class Task (How to make password Stronger)

# %%
password = input("Create a password: ")

if len(password) >= 8:
    print("Strong Password - Access Granted")
else:
    print("Weak Password - Password must contain at least 8 characters")
# Out:
# Create a password:  rohit@23456789
# Strong Password - Access Granted
