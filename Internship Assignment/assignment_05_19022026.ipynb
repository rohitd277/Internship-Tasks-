# %% [markdown]
# *Assignment (19/02/2026)*
# *Assignment Name* : Student Data Manager
# *Description* : Store data for 5 students using dictionaries, print topper, class average, and assign grades.

# %%
students = {}

# Input data for 5 students
for i in range(5):
    name = input("Enter student name: ")
    marks = int(input("Enter marks: "))
    students[name] = marks

# Find topper
topper = max(students, key=students.get)

# Calculate class average
average = sum(students.values()) / len(students)

print("\nStudent Marks:", students)
print("Topper:", topper, "-", students[topper])
print("Class Average:", average)

# Assign grades
print("\nGrades:")
for name, marks in students.items():
    if marks >= 90:
        grade = "A"
    elif marks >= 75:
        grade = "B"
    elif marks >= 50:
        grade = "C"
    else:
        grade = "Fail"
        
    print(name, ":", grade)
# Out:
# Enter student name:  Rohit
# Enter marks:  45
# Enter student name:  jjk
# Enter marks:  56
# Enter student name:  you
# Enter marks:  44
# Enter student name:  uiui
# Enter marks:  30
# Enter student name:  jjkjk
# Enter marks:  41
# Student Marks: {'Rohit': 45, 'jjk': 56, 'you': 44, 'uiui': 30, 'jjkjk': 41}
# Topper: jjk - 56
# Class Average: 43.2
#
# Grades:
# Rohit : Fail
# jjk : C
# you : Fail
# uiui : Fail
# jjkjk : Fail
