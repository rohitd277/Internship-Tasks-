# %% [markdown]
# *Assignment (21/03/2026)*
# *Assignment Name* : Build a Text Cleaner
# *Description* : Write code to remove punctuation, lowercase text, remove stopwords and test it.

# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

sentences = [
    "Hey bro 😎 what's up!!!",
    "I luv this movie soooo much!!!",
    "LOL that was funny 😂😂"
]

df = pd.DataFrame({"Text": sentences})

def clean_text(text):
    # Lowercase
    text = text.lower()
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove stopwords
    words = text.split()
    words = [word for word in words if word not in ENGLISH_STOP_WORDS]
    
    return " ".join(words)

df["Cleaned_Text"] = df["Text"].apply(clean_text)

print(df)
# Out:
#                              Text     Cleaned_Text
# 0          Hey bro 😎 what's up!!!  hey bro 😎 whats
# 1  I luv this movie soooo much!!!  luv movie soooo
# 2           LOL that was funny 😂😂     lol funny 😂😂
