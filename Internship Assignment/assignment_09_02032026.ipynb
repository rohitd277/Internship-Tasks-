# %% [markdown]
# *Assignment (02/03/2026)*
# *Assignment Name* : ML Idea Generator
# *Description* : Suggest ML problems in college, healthcare, shopping and describe input → output.

# %%
print("ML IDEA GENERATOR\n")

print("1. COLLEGE DOMAIN")
print("Problem: Student Performance Prediction")
print("Input  : Study hours, attendance, assignment scores")
print("Output : Predicted final exam marks or grade\n")

print("2. HEALTHCARE DOMAIN")
print("Problem: Disease Risk Prediction")
print("Input  : Age, weight, blood pressure, glucose level")
print("Output : Probability of having a disease (e.g., diabetes)\n")

print("3. SHOPPING DOMAIN")
print("Problem: Product Recommendation System")
print("Input  : User purchase history, product ratings, browsing data")
print("Output : Recommended products for the user\n")

print("4. COLLEGE FACILITY DOMAIN")
print("Problem: Library Book Demand Prediction")
print("Input  : Book issue history, student department, semester")
print("Output : Predict which books will be in high demand\n")
# Out:
# ML IDEA GENERATOR
#
# 1. COLLEGE DOMAIN
# Problem: Student Performance Prediction
# Input  : Study hours, attendance, assignment scores
# Output : Predicted final exam marks or grade
#
# 2. HEALTHCARE DOMAIN
# Problem: Disease Risk Prediction
# Input  : Age, weight, blood pressure, glucose level
# Output : Probability of having a disease (e.g., diabetes)
#
# 3. SHOPPING DOMAIN
# Problem: Product Recommendation System
# Input  : User purchase history, product ratings, browsing data
# Output : Recommended products for the user
#
# 4. COLLEGE FACILITY DOMAIN
# Problem: Library Book Demand Prediction
# Input  : Book issue history, student department, semester
# Output : Predict which books will be in high demand
