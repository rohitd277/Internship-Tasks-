# %%
cart = ["Milk", "Bread", "Eggs", "Butter"]

# %%
print("Shopping Cart:", cart)
# Out:
# Shopping Cart: ['Milk', 'Bread', 'Eggs', 'Butter']

# %%
cart.remove("Eggs")

# %%
print("Cart after removing item:", cart)
# Out:
# Cart after removing item: ['Milk', 'Bread', 'Butter']

# %%
len(cart)
# Out:
# 3
