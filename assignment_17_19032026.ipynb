# %% [markdown]
# *Assignment (19/03/2026)*
# *Assignment Name* : Mini Project Proposal
# *Description* : Submit a 1-page proposal with problem, dataset, algorithm, expected output.

# %%
import pandas as pd

# Complete Mini Project Proposal
proposal = {
    "Title": "Movie Recommendation System",
    
    "Problem Statement": (
        "Users often struggle to find movies that match their interests "
        "due to the large number of available options."
    ),
    
    "Objective": (
        "To build a machine learning system that recommends movies "
        "based on user preferences and similarity between movies."
    ),
    
    "Dataset": (
        "Movie dataset containing movie titles, genres, and user ratings. "
        "Example: ratings.csv, movies.csv"
    ),
    
    "Features (Input)": (
        "User ratings, movie genres, previously watched movies"
    ),
    
    "Algorithm": (
        "K-Nearest Neighbors (KNN) to find similar movies based on user behavior"
    ),
    
    "Working": (
        "The system compares movies using similarity measures. "
        "It finds nearest movies using KNN and recommends them to the user."
    ),
    
    "Expected Output": (
        "List of recommended movies similar to user's interest"
    ),
    
    "Evaluation": (
        "Accuracy of recommendations, user satisfaction, and relevance of results"
    ),
    
    "Future Scope": (
        "Improve recommendations using deep learning and real-time user feedback"
    )
}

# Convert to DataFrame
df = pd.DataFrame(list(proposal.items()), columns=["Section", "Details"])

# Display neatly
print("MINI PROJECT PROPOSAL\n")

for index, row in df.iterrows():
    print(row["Section"].upper())
    print(row["Details"])
    print("\n")
# Out:
# MINI PROJECT PROPOSAL
#
# TITLE
# Movie Recommendation System
#
#
# PROBLEM STATEMENT
# Users often struggle to find movies that match their interests due to the large number of available options.
#
#
# OBJECTIVE
# To build a machine learning system that recommends movies based on user preferences and similarity between movies.
#
#
# DATASET
# Movie dataset containing movie titles, genres, and user ratings. Example: ratings.csv, movies.csv
#
#
# FEATURES (INPUT)
# User ratings, movie genres, previously watched movies
#
#
# ALGORITHM
# K-Nearest Neighbors (KNN) to find similar movies based on user behavior
#
#
# WORKING
# The system compares movies using similarity measures. It finds nearest movies using KNN and recommends them to the user.
#
#
# EXPECTED OUTPUT
# List of recommended movies similar to user's interest
#
#
# EVALUATION
# Accuracy of recommendations, user satisfaction, and relevance of results
#
#
# FUTURE SCOPE
# ...
